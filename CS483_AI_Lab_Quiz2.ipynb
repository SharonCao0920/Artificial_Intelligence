# %% [markdown]
# <a href="https://colab.research.google.com/github/SharonCao0920/AI/blob/main/CS483_AI_Lab_Quiz2.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
"""
1.Write a program to implement Bootstrapping algorithm to find the median number 
in the given dataset shown in file “Bootstrapping example” 

*Notice that it is suggested to create 10 new sets randomly 
"""
import numpy as np

dataset=[12,99,45,78,34]

print("The original dataset is:\n",dataset)
print("mean of the original sample",np.mean(dataset))

#mean list to hold mean value for each Bootstrap
mean_list=[]
#bootstrap_data to hold all 10,000 random datasets
bootstrap_data=[]

#iterate to generate dataset and mean of each set
#*Notice that it is suggested to create 10 new sets randomly
#using larger number of set for better result show
for i in range(50):
  sample=np.random.choice(dataset,size=5)
  bootstrap_data.append(sample)
  mean_list.append(sample.mean())

#print boostrap datasets
for i in range(1,len(bootstrap_data)+1):  
  print("--------------------")
  print("Bootstrap No.", i)
  print(bootstrap_data[i-1])

#print mean values of each bootstrap
print("---------------------------------------------")
print("Mean of Each Bootstrap:")
for i in range(1,len(mean_list)+1):
  print("Mean of Bootstrap No.", i, "\t", mean_list[i-1])

#create dic to store mean and frenquency
frequency = {}
for mean in mean_list:
   if mean in frequency:
      frequency[mean] += 1
   else:
      frequency[mean] = 1

# printing the frequency
print("--------------------")
print("Mean\tFrequency ")
for key, value in frequency.items():
  print(key,"\t",value)
#plot frequency for 
import matplotlib.pyplot as plt

names = list(frequency.keys())
values = list(frequency.values())

print("")
plt.bar(range(len(frequency)), frequency.values())
plt.title("Mean of Bootstrap with Frequency")
plt.ylabel("Frequency")
plt.xticks(range(len(frequency)), frequency.keys())
plt.show()

#print the mean value
for key, value in frequency.items():
  if value == max(frequency.values(),):
    print("Mean calculated by Bootstrap Method is: ",key)
# Out:
# The original dataset is:
#  [12, 99, 45, 78, 34]
# mean of the original sample 53.6
# --------------------
# Bootstrap No. 1
# [99 12 34 99 12]
# --------------------
# Bootstrap No. 2
# [78 12 45 12 99]
# --------------------
# Bootstrap No. 3
# [78 78 34 99 12]
# --------------------
# Bootstrap No. 4
# [78 45 45 45 78]
# --------------------
# Bootstrap No. 5
# [12 99 99 78 99]
# --------------------
# Bootstrap No. 6
# [34 45 34 45 34]
# --------------------
# Bootstrap No. 7
# [78 34 99 12 78]
# --------------------
# Bootstrap No. 8
# [99 12 78 12 78]
# --------------------
# Bootstrap No. 9
# [34 12 45 34 34]
# --------------------
# Bootstrap No. 10
# [12 99 12 99 78]
# --------------------
# Bootstrap No. 11
# [99 99 99 78 12]
# --------------------
# Bootstrap No. 12
# [78 45 99 12 34]
# --------------------
# Bootstrap No. 13
# [99 12 12 78 99]
# --------------------
# Bootstrap No. 14
# [99 78 78 34 12]
# --------------------
# Bootstrap No. 15
# [45 12 78 78 78]
# --------------------
# Bootstrap No. 16
# [45 34 12 99 34]
# --------------------
# Bootstrap No. 17
# [34 78 12 12 12]
# --------------------
# Bootstrap No. 18
# [99 99 12 78 99]
# --------------------
# Bootstrap No. 19
# [45 34 45 78 78]
# --------------------
# Bootstrap No. 20
# [78 12 45 78 78]
# --------------------
# Bootstrap No. 21
# [12 78 99 12 12]
# --------------------
# Bootstrap No. 22
# [99 78 34 34 99]
# --------------------
# Bootstrap No. 23
# [34 99 12 45 99]
# --------------------
# Bootstrap No. 24
# [99 12 45 78 12]
# --------------------
# Bootstrap No. 25
# [78 34 45 34 45]
# --------------------
# Bootstrap No. 26
# [99 99 34 99 78]
# --------------------
# Bootstrap No. 27
# [45 99 12 78 34]
# --------------------
# Bootstrap No. 28
# [12 12 78 78 34]
# --------------------
# Bootstrap No. 29
# [99 99 78 12 45]
# --------------------
# Bootstrap No. 30
# [99 78 45 99 78]
# --------------------
# Bootstrap No. 31
# [99 45 45 12 45]
# --------------------
# Bootstrap No. 32
# [99 34 12 45 45]
# --------------------
# Bootstrap No. 33
# [34 78 34 99 99]
# --------------------
# Bootstrap No. 34
# [45 78 78 12 34]
# --------------------
# Bootstrap No. 35
# [78 78 78 45 45]
# --------------------
# Bootstrap No. 36
# [99 34 45 99 34]
# --------------------
# Bootstrap No. 37
# [45 78 99 12 78]
# --------------------
# Bootstrap No. 38
# [78 99 34 45 99]
# --------------------
# Bootstrap No. 39
# [78 45 78 12 12]
# --------------------
# Bootstrap No. 40
# [34 12 78 99 78]
# --------------------
# Bootstrap No. 41
# [99 78 45 45 78]
# --------------------
# Bootstrap No. 42
# [12 78 34 12 99]
# --------------------
# Bootstrap No. 43
# [45 99 12 45 78]
# --------------------
# Bootstrap No. 44
# [99 34 12 12 78]
# --------------------
# Bootstrap No. 45
# [99 99 34 45 34]
# --------------------
# Bootstrap No. 46
# [12 78 45 99 45]
# --------------------
# Bootstrap No. 47
# [34 45 12 45 78]
# --------------------
# Bootstrap No. 48
# [99 99 34 99 99]
# --------------------
# Bootstrap No. 49
# [12 12 78 78 12]
# --------------------
# Bootstrap No. 50
# [99 99 99 78 45]
# ---------------------------------------------
# Mean of Each Bootstrap:
# Mean of Bootstrap No. 1 	 51.2
# Mean of Bootstrap No. 2 	 49.2
# Mean of Bootstrap No. 3 	 60.2
# Mean of Bootstrap No. 4 	 58.2
# Mean of Bootstrap No. 5 	 77.4
# Mean of Bootstrap No. 6 	 38.4
# Mean of Bootstrap No. 7 	 60.2
# Mean of Bootstrap No. 8 	 55.8
# Mean of Bootstrap No. 9 	 31.8
# Mean of Bootstrap No. 10 	 60.0
# Mean of Bootstrap No. 11 	 77.4
# Mean of Bootstrap No. 12 	 53.6
# Mean of Bootstrap No. 13 	 60.0
# Mean of Bootstrap No. 14 	 60.2
# Mean of Bootstrap No. 15 	 58.2
# Mean of Bootstrap No. 16 	 44.8
# Mean of Bootstrap No. 17 	 29.6
# Mean of Bootstrap No. 18 	 77.4
# Mean of Bootstrap No. 19 	 56.0
# Mean of Bootstrap No. 20 	 58.2
# Mean of Bootstrap No. 21 	 42.6
# Mean of Bootstrap No. 22 	 68.8
# Mean of Bootstrap No. 23 	 57.8
# Mean of Bootstrap No. 24 	 49.2
# Mean of Bootstrap No. 25 	 47.2
# Mean of Bootstrap No. 26 	 81.8
# Mean of Bootstrap No. 27 	 53.6
# Mean of Bootstrap No. 28 	 42.8
# Mean of Bootstrap No. 29 	 66.6
# Mean of Bootstrap No. 30 	 79.8
# Mean of Bootstrap No. 31 	 49.2
# Mean of Bootstrap No. 32 	 47.0
# Mean of Bootstrap No. 33 	 68.8
# Mean of Bootstrap No. 34 	 49.4
# Mean of Bootstrap No. 35 	 64.8
# Mean of Bootstrap No. 36 	 62.2
# Mean of Bootstrap No. 37 	 62.4
# Mean of Bootstrap No. 38 	 71.0
# Mean of Bootstrap No. 39 	 45.0
# Mean of Bootstrap No. 40 	 60.2
# Mean of Bootstrap No. 41 	 69.0
# Mean of Bootstrap No. 42 	 47.0
# Mean of Bootstrap No. 43 	 55.8
# Mean of Bootstrap No. 44 	 47.0
# Mean of Bootstrap No. 45 	 62.2
# Mean of Bootstrap No. 46 	 55.8
# Mean of Bootstrap No. 47 	 42.8
# Mean of Bootstrap No. 48 	 86.0
# Mean of Bootstrap No. 49 	 38.4
# Mean of Bootstrap No. 50 	 84.0
# --------------------
# Mean	Frequency
# 51.2 	 1
# 49.2 	 3
# 60.2 	 4
# 58.2 	 3
# 77.4 	 3
# 38.4 	 2
# 55.8 	 3
# 31.8 	 1
# 60.0 	 2
# 53.6 	 2
# 44.8 	 1
# 29.6 	 1
# 56.0 	 1
# 42.6 	 1
# 68.8 	 2
# 57.8 	 1
# 47.2 	 1
# 81.8 	 1
# 42.8 	 2
# 66.6 	 1
# 79.8 	 1
# 47.0 	 3
# 49.4 	 1
# 64.8 	 1
# 62.2 	 2
# 62.4 	 1
# 71.0 	 1
# 45.0 	 1
# 69.0 	 1
# 86.0 	 1
# 84.0 	 1
# Mean calculated by Bootstrap Method is:  60.2
